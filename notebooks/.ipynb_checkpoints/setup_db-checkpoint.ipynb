# %% [markdown]
# # Setup
#
# We first need to import packages, load secret credentials, and set up a connection to MySQL.

# %%
import mysql.connector
import os
from github import Github
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
mysql_user = os.getenv("MYSQL_USER")
mysql_pass = os.getenv("MYSQL_PASS")
gh_token = os.getenv("GH_TOKEN")

# %%
cnx = mysql.connector.connect(user=mysql_user, password=mysql_pass,
                              host='127.0.0.1',
                              database='final_proj')

# %% [markdown]
# # Get data

# %%
g = Github(gh_token)
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# aicoe-newsletter
# ai-ci
# AI-Stacks-pipeline
# aicoe-cd
# aicoe-ci
# aicoe-sre
# anomaly-detection-demo-app
# Awesome-Data-Science-with-Python
# benchmarks-tekton
# clai
# common
# content-pipeline
# data-driven-development
# disk-failure-prediction
# donkeycar
# edge-tekton-model
# edge-tekton-pipeline
# elyra-aidevsecops-tutorial
# EthicalML-awesome-production-machine-learning
# experiment-tracking
# experiment-tracking-template
# frauddetection-producer-consumer
# idh-manifests
# inference
# inference_results_v0.5
# instrumented-app-go
# instrumented-app-prometheus
# internal-data-hub
# jpegio
# jupyter-notebooks
# jupyterhub-operator
# kubectl-container
# kubeflow
# learn-katacoda
# log-anomaly-detector
# ludus
# manage-dependencies-tutorial
# matmul-pipeline-cpu
# matmul-pipeline-gpu
# meteor
# meteor-operator
# mlflow-tracking-operator
# mlperf-inference-tekton-pipeline
# mlperf-tekton
# mlperf-training
# mlperf_metric_collection
# okr
# olm-testing-example
# olm-testing-example-fork
# OpenShiftKubeAudit
# openshift_kubeflow_workshop
# overlays-for-ai-pipeline-tutorial
# peak
# peak-fork
# pl-tensorflowapp
# pricingnbs
# prometheus-anomaly-detector
# prometheus-anomaly-detector-legacy
# prometheus-api-client-python
# prometheus-data-science
# prometheus-flatliner
# prometheus-influx
# prometheus-lts
# prometheus-remote-storage-adapter
# prometheus-scraper
# pyIFD
# pytorch-lda2vec
# receive-feedback-on-deployment-tutorial
# recommend-base-image-tutorial
# repartitioning-sosreports
# repository-knowledge-refresh-job
# robo-doc
# s2i-custom-notebook
# safety-db
# sefkhet-abwy
# seraph
# sesheta
# starburst-test
# stats-to-serverless-on-OpenShift4
# summit-2021-octo-keynote
# tensorflow-serving-s2i
# tensorflow-wheels
# tf-in-container
# tf-serving-in-container
# thanos-openshift
# ultrahook
# v0.6_mlperf_training_DellC4140
# Varangian
# workshop-coding-best-practices
# workshop-intern-bootcamp-git
# ai-enablement-initiative
# ansible-automation-analytics
# auto-faq
# categorical-encoding
# categorical-encoding-internal
# ceph-data-drive-failure
# ceph_drive_failure
# cja-topic-modeling
# cloud-price-analysis
# cloud-price-analysis-public
# common
# configuration-files-analysis
# cookiecutter-aicoe-ds
# cookiecutter-data-science
# cpaas-automated-failure-analysis
# data-science-workflow-examples
# data-science-workflows
# disk-health-predictor
# fedora-mailing-list-analysis
# flake-qe
# github-labeler
# HTM-applications
# insights-configuration-files-analysis
# insights-drift-analysis-baselines
# insights-grokket
# insights-invocation-hints
# insights-sap-analysis
# mailing-list-analysis-toolkit
# meteor-demo
# ocp-alert-prediction
# ocp-alert-prediction-public
# ocp-ci-analysis
# ocp4-anomaly-detection-internal
# openshift-anomaly-detection
# openshift-sme-mailing-list-analysis
# openshift-workload-fingerprinting
# operate-first-data-science-community
# operate-first-jupyterhub-analysis
# operate-first-openshift-data
# performance-qe
# pet-image-detection
# project-template
# ri-optimization
# sentiment-analysis-demo
# sentiment-analysis-public
# sync-pipelines
# sync-pipelines-private
# time-series
# vulnerability-analysis
# wine_reviews_data_analysis
# DMTM_FA2020
# kaggle-competition-isabelizimm
# Fall2021
# aicoe-ci
# aicoe-newsletter
# alibi
# apps
# augur-community-reports
# brunch-invite
# ceph_drive_failure
# community
# content-pipeline
# db-final-proj
# disk-health-predictor
# edge-anomaly-detection
# elyra-aidevsecops-tutorial
# fa21organization
# flpoly_DS_2020
# h4d-flpoly-dsba
# hai-project
# hai-project-in-r
# hitchhikers-guide
# iml
# isabelizimm
# isabelizimm.github.io
# mailing-list-analysis-toolkit
# mapreduce-text-mining
# meteor
# meteor-demo
# minima
# ocp-ci-analysis
# openshift-ml-workflows-workshop
# operate-first-twitter
# operate-first.github.io
# pet-image-detection
# pipeline-testing
# postgresql-container
# sandiego
# scholars-template
# simple-model-s2i
# site
# SRE
# time-series
# stats_learning_project
# opendatapolicing
# opendatapolicing-ansible
# opendatapolicing-static
# alertmanager-github-receiver
# alerts
# apps
# argocd-apps
# blueprint
# common
# community
# community-handbook
# continuous-delivery
# continuous-deployment
# curator
# espresso-series
# example-acm-install
# hetzner-baremetal-openshift
# hitchhikers-guide
# installplan-operator
# odh-dashboard
# operate-first-twitter
# operate-first.github.io
# opfcli
# schema-store
# SRE
# sre-apprenticeship
# support
# template
# toolbox
# workshop-apps
# amqp-client
# ansible-role-ansible_bastion
# ansible-role-firewall_facts
# ansible-role-freeipa
# ansible-role-httpd
# ansible-role-ipa_facts
# ansible-role-mariadb
# ansible-role-openssh
# ansible-role-polyinst_tmp
# ansible-role-rsyslog
# ansible-role-salt_transport
# ansible-role-selinux
# ansible-role-swap_file
# ansible-role-web_builder
# apps.fp.o
# comminfra-docs-sle-template
# community-website
# event-tools
# github-pluto-feeds
# github-pluto-moderate-posts
# jekyll-haml
# middleman-planet
# middleman-springboard
# moderated_planet_prototype
# mountpoint
# mw2md
# posse-tos-logos
# Practical-OSS-Exploration-textbook
# project-presos
# rh-events
# s2i-golang
# s2i-middleman
# sensor
# strapping-mediawiki
# tos-repository
# twitter-stats
# DO180-apps
# documentation
# how-do-I-documentation
# nlp-tweet-sentiments
# notebook-samples
# odh-s2i-project-cookiecutter
# odh-s2i-project-simple
# odh-s2i-scripts
# pilot-test-code
# postgres-operator-examples
# pricingnbs
# pytorch-diabetes
# pytorch-openvino
# pytorch-openvino-1
# RHSummit2019
# test-repo-lb
# testGPUs
# tgtaegdfg
# weather_data_elyra_pipeline_example
# welly-geoscience
# sandiego

# %%
# store the repos into a list
repos = list(g.get_user().get_repos())

# %%
test_repo = repos[0]
print(repo.raw_data)
# Out:
# {'id': 366816677, 'node_id': 'MDEwOlJlcG9zaXRvcnkzNjY4MTY2Nzc=', 'name': 'sandiego', 'full_name': 'sandiego-rh/sandiego', 'private': False, 'owner': {'login': 'sandiego-rh', 'id': 88001610, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg4MDAxNjEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/88001610?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sandiego-rh', 'html_url': 'https://github.com/sandiego-rh', 'followers_url': 'https://api.github.com/users/sandiego-rh/followers', 'following_url': 'https://api.github.com/users/sandiego-rh/following{/other_user}', 'gists_url': 'https://api.github.com/users/sandiego-rh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sandiego-rh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sandiego-rh/subscriptions', 'organizations_url': 'https://api.github.com/users/sandiego-rh/orgs', 'repos_url': 'https://api.github.com/users/sandiego-rh/repos', 'events_url': 'https://api.github.com/users/sandiego-rh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sandiego-rh/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/sandiego-rh/sandiego', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/sandiego-rh/sandiego', 'forks_url': 'https://api.github.com/repos/sandiego-rh/sandiego/forks', 'keys_url': 'https://api.github.com/repos/sandiego-rh/sandiego/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/sandiego-rh/sandiego/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/sandiego-rh/sandiego/teams', 'hooks_url': 'https://api.github.com/repos/sandiego-rh/sandiego/hooks', 'issue_events_url': 'https://api.github.com/repos/sandiego-rh/sandiego/issues/events{/number}', 'events_url': 'https://api.github.com/repos/sandiego-rh/sandiego/events', 'assignees_url': 'https://api.github.com/repos/sandiego-rh/sandiego/assignees{/user}', 'branches_url': 'https://api.github.com/repos/sandiego-rh/sandiego/branches{/branch}', 'tags_url': 'https://api.github.com/repos/sandiego-rh/sandiego/tags', 'blobs_url': 'https://api.github.com/repos/sandiego-rh/sandiego/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/sandiego-rh/sandiego/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/sandiego-rh/sandiego/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/sandiego-rh/sandiego/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/sandiego-rh/sandiego/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/sandiego-rh/sandiego/languages', 'stargazers_url': 'https://api.github.com/repos/sandiego-rh/sandiego/stargazers', 'contributors_url': 'https://api.github.com/repos/sandiego-rh/sandiego/contributors', 'subscribers_url': 'https://api.github.com/repos/sandiego-rh/sandiego/subscribers', 'subscription_url': 'https://api.github.com/repos/sandiego-rh/sandiego/subscription', 'commits_url': 'https://api.github.com/repos/sandiego-rh/sandiego/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/sandiego-rh/sandiego/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/sandiego-rh/sandiego/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/sandiego-rh/sandiego/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/sandiego-rh/sandiego/contents/{+path}', 'compare_url': 'https://api.github.com/repos/sandiego-rh/sandiego/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/sandiego-rh/sandiego/merges', 'archive_url': 'https://api.github.com/repos/sandiego-rh/sandiego/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/sandiego-rh/sandiego/downloads', 'issues_url': 'https://api.github.com/repos/sandiego-rh/sandiego/issues{/number}', 'pulls_url': 'https://api.github.com/repos/sandiego-rh/sandiego/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/sandiego-rh/sandiego/milestones{/number}', 'notifications_url ...

# %%
# get the 'main' branch and print the raw data
branch = repo.get_branch("main")
#print(branch.raw_data)
# get the first commit item form commits
commit = None
for c in repo.get_commits():
    commit = c
    break # we break here to only have the first iteration
# print the commit raw data
#print(commit.raw_data)

# %%
commits_data = {
"repo_id": int(repo.id),
"commit_sha": commit.sha,
"commit_message": commit.commit.message,
"commit_author_name": commit.commit.author.name,
"commit_author_email": commit.commit.author.email,
"commit_author_date": commit.commit.author.date,
"commit_committer_name": commit.commit.committer.name,
"commit_committer_email": commit.commit.committer.email,
"commit_committer_date": commit.commit.committer.date,
"author_login": commit.author.login,
"author_id": commit.author.id,
"author_avatar_url": commit.author.avatar_url,
"author_type": commit.author.type,
"committer_login": commit.committer.login,
"committer_id": commit.committer.id,
"committer_avatar_url": commit.committer.avatar_url,
"committer_type": commit.committer.type,
"stats_addtions": commit.stats.additions,
"stats_deletions": commit.stats.deletions,
"stats_total": commit.stats.total
}

# %%
#file_data = {
#"id": ,
#"commit_id": ,
#"repo_id": ,
#"file_name": ,
#"addtions": ,
#"deletions": ,
#"changes": ,
#"status":
#}

# %%
repo_data = {
"id": repo.id,
"name": repo.name,
"owner": repo.owner.login,
"fullname": repo.full_name,
"description": repo.description,
"url": repo.url,
"pushed_date": int(repo.pushed_at.timestamp()),
"created_date": int(repo.created_at.timestamp()),
"updated_date": int(repo.updated_at.timestamp()),
"size": repo.size,
"stars": repo.stargazers_count,
"forks": repo.forks_count,
"watchers": repo.watchers_count,
"language": repo.language,
"topics": ",".join(repo.get_topics()),
}

# %%
branch_data = {
"id": repo.id,
"repo_id": int(repo.id),
"name": branch.name,
"commit_sha": branch.commit.sha,
"protected": int(branch.protected)
}

# %%
ddl = """
CREATE TABLE IF NOT EXISTS repo(
id integer PRIMARY KEY,
name VARCHAR(255) NOT NULL,
owner VARCHAR(255) NOT NULL,
fullname VARCHAR(511) NOT NULL,
description TEXT NOT NULL,
url VARCHAR(511) NOT NULL,
pushed_date INTEGER NOT NULL,
created_date INTEGER NOT NULL,
updated_date INTEGER NOT NULL,
size INTEGER NOT NULL,
stars INTEGER NOT NULL,
forks INTEGER NOT NULL,
watchers INTEGER NOT NULL,
language VARCHAR(255) NOT NULL,
topics TEXT NOT NULL
);
CREATE TABLE IF NOT EXISTS branch(
id integer PRIMARY KEY,
repo_id INTEGER NOT NULL,
name VARCHAR(255) NOT NULL,
commit_sha VARCHAR(255) NOT NULL,
protected  INTEGER NOT NULL,
FOREIGN KEY (repo_id) REFERENCES repo (id)
);
CREATE TABLE IF NOT EXISTS commits(
id integer PRIMARY KEY,
repo_id INTEGER NOT NULL,
commit_sha VARCHAR(255) NOT NULL,
commit_message TEXT NOT NULL,
commit_author_name VARCHAR(255) NOT NULL,
commit_author_email VARCHAR(255) NOT NULL,
commit_author_date INTEGER NOT NULL,
commit_committer_name VARCHAR(255) NOT NULL,
commit_committer_email VARCHAR(255) NOT NULL,
commit_committer_date INTEGER NOT NULL,
author_login VARCHAR(255)  NULL,
author_id INTEGER NULL,
author_avatar_url VARCHAR(255) NULL,
author_type VARCHAR(255) NULL,
committer_login VARCHAR(255) NULL,
committer_id INTEGER NULL,
committer_avatar_url VARCHAR(255) NULL,
committer_type VARCHAR(255) NULL,
stats_addtions INTEGER NOT NULL,
stats_deletions INTEGER NOT NULL,
stats_total INTEGER NOT NULL,
FOREIGN KEY (repo_id) REFERENCES repo (id)
);
CREATE TABLE IF NOT EXISTS commit_file(
id integer PRIMARY KEY,
commit_id INTEGER NOT NULL,
repo_id INTEGER NOT NULL,
file_name VARCHAR(255) NOT NULL,
addtions INTEGER NOT NULL,
deletions INTEGER NOT NULL,
changes INTEGER NOT NULL,
status VARCHAR(255) NOT NULL,
FOREIGN KEY (commit_id) REFERENCES commits (id),
FOREIGN KEY (repo_id) REFERENCES repo (id)
);
"""

# %%
cursor = cnx.cursor(dictionary=True)
cursor.execute(ddl)

# %%
repo_columns = list(repo_data.keys())
branch_columns = list(branch_data.keys())
#file_columns = list(file_data.keys())
commits_columns = list(commits_data.keys())

# %%
values = [repo_data[k] for k in repo_columns]

# %%
query = """INSERT INTO repo {0} VALUES ({1})""".format(repo_columns, values)
print(query)
# Out:
# INSERT INTO repo ['id', 'name', 'owner', 'fullname', 'description', 'url', 'pushed_date', 'created_date', 'updated_date', 'size', 'stars', 'forks', 'watchers', 'language', 'topics'] VALUES ([366816677, 'sandiego', 'sandiego-rh', 'sandiego-rh/sandiego', None, 'https://api.github.com/repos/sandiego-rh/sandiego', 1637218396, 1620858824, 1635799369, 25597, 2, 7, 2, 'Jupyter Notebook', ''])

# %%
cursor.execute(query,list)

cursor.commit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/z0/372wwcyd2y105vm5m9v8br4m0000gn/T/ipykernel_6541/631354373.py in <module>
# ----> 1 cursor.execute(query,list)
#       2
#       3 cursor.commit()
#
# /usr/local/lib/python3.9/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     255
#     256         if params:
# --> 257             prepared = self._cnx.prepare_for_mysql(params)
#     258             if isinstance(prepared, dict):
#     259                 for key, value in prepared.items():
#
# /usr/local/lib/python3.9/site-packages/mysql/connector/connection_cext.py in prepare_for_mysql(self, params)
#     657                 result[key] = self._cmysql.convert_to_mysql(value)[0]
#     658         else:
# --> 659             raise ValueError("Could not process parameters")
#     660
#     661         return result
#
# ValueError: Could not process parameters

# %%
cnx.close()
