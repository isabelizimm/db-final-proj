# %% [markdown]
# # Load data
#
# Since we closed the connection to our database in the [first notebook](./01-ddl.ipynb), we will first start by creating this connection again
#
# To reproduce this step locally, you will need to generate a GitHub personal access token. Find a tutorial on how to do this [here](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token).

# %%
import mysql.connector
import os
from github import Github
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
mysql_user = os.getenv("MYSQL_USER")
mysql_pass = os.getenv("MYSQL_PASS")
gh_token = os.getenv("GH_TOKEN")

# %%
cnx = mysql.connector.connect(user=mysql_user, password=mysql_pass,
                              host='127.0.0.1',
                              database='final_proj')
g = Github(gh_token)

# %% [markdown]
# # Get data

# %%
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# aicoe-newsletter
# ai-ci
# AI-Stacks-pipeline
# aicoe-cd
# aicoe-ci
# aicoe-sre
# anomaly-detection-demo-app
# Awesome-Data-Science-with-Python
# benchmarks-tekton
# clai
# common
# content-pipeline
# data-driven-development
# disk-failure-prediction
# donkeycar
# edge-tekton-model
# edge-tekton-pipeline
# elyra-aidevsecops-tutorial
# EthicalML-awesome-production-machine-learning
# experiment-tracking
# experiment-tracking-template
# frauddetection-producer-consumer
# idh-manifests
# inference
# inference_results_v0.5
# instrumented-app-go
# instrumented-app-prometheus
# internal-data-hub
# jpegio
# jupyter-notebooks
# jupyterhub-operator
# kubectl-container
# kubeflow
# learn-katacoda
# log-anomaly-detector
# ludus
# manage-dependencies-tutorial
# matmul-pipeline-cpu
# matmul-pipeline-gpu
# meteor
# meteor-operator
# mlflow-tracking-operator
# mlperf-inference-tekton-pipeline
# mlperf-tekton
# mlperf-training
# mlperf_metric_collection
# okr
# olm-testing-example
# olm-testing-example-fork
# OpenShiftKubeAudit
# openshift_kubeflow_workshop
# overlays-for-ai-pipeline-tutorial
# peak
# peak-fork
# pl-tensorflowapp
# pricingnbs
# prometheus-anomaly-detector
# prometheus-anomaly-detector-legacy
# prometheus-api-client-python
# prometheus-data-science
# prometheus-flatliner
# prometheus-influx
# prometheus-lts
# prometheus-remote-storage-adapter
# prometheus-scraper
# pyIFD
# pytorch-lda2vec
# receive-feedback-on-deployment-tutorial
# recommend-base-image-tutorial
# repartitioning-sosreports
# repository-knowledge-refresh-job
# robo-doc
# s2i-custom-notebook
# safety-db
# sefkhet-abwy
# seraph
# sesheta
# starburst-test
# stats-to-serverless-on-OpenShift4
# summit-2021-octo-keynote
# tensorflow-serving-s2i
# tensorflow-wheels
# tf-in-container
# tf-serving-in-container
# thanos-openshift
# ultrahook
# v0.6_mlperf_training_DellC4140
# Varangian
# workshop-coding-best-practices
# workshop-intern-bootcamp-git
# ai-enablement-initiative
# ansible-automation-analytics
# auto-faq
# categorical-encoding
# categorical-encoding-internal
# ceph-data-drive-failure
# ceph_drive_failure
# cja-topic-modeling
# cloud-price-analysis
# cloud-price-analysis-public
# common
# configuration-files-analysis
# cookiecutter-aicoe-ds
# cookiecutter-data-science
# cpaas-automated-failure-analysis
# data-science-workflow-examples
# data-science-workflows
# disk-health-predictor
# fedora-mailing-list-analysis
# flake-qe
# github-labeler
# HTM-applications
# insights-configuration-files-analysis
# insights-drift-analysis-baselines
# insights-grokket
# insights-invocation-hints
# insights-sap-analysis
# mailing-list-analysis-toolkit
# meteor-demo
# ocp-alert-prediction
# ocp-alert-prediction-public
# ocp-ci-analysis
# ocp4-anomaly-detection-internal
# openshift-anomaly-detection
# openshift-sme-mailing-list-analysis
# openshift-workload-fingerprinting
# operate-first-data-science-community
# operate-first-jupyterhub-analysis
# operate-first-openshift-data
# performance-qe
# pet-image-detection
# project-template
# ri-optimization
# sentiment-analysis-demo
# sentiment-analysis-public
# sync-pipelines
# sync-pipelines-private
# time-series
# vulnerability-analysis
# wine_reviews_data_analysis
# DMTM_FA2020
# kaggle-competition-isabelizimm
# Fall2021
# aicoe-ci
# aicoe-newsletter
# alibi
# apps
# augur-community-reports
# brunch-invite
# ceph_drive_failure
# community
# content-pipeline
# db-final-proj
# disk-health-predictor
# edge-anomaly-detection
# elyra-aidevsecops-tutorial
# fa21organization
# flpoly_DS_2020
# h4d-flpoly-dsba
# hai-project
# hai-project-in-r
# hitchhikers-guide
# iml
# isabelizimm
# isabelizimm.github.io
# mailing-list-analysis-toolkit
# mapreduce-text-mining
# meteor
# meteor-demo
# minima
# ocp-ci-analysis
# openshift-ml-workflows-workshop
# operate-first-twitter
# operate-first.github.io
# pet-image-detection
# pipeline-testing
# postgresql-container
# sandiego
# scholars-template
# simple-model-s2i
# site
# SRE
# time-series
# stats_learning_project
# opendatapolicing
# opendatapolicing-ansible
# opendatapolicing-static
# alertmanager-github-receiver
# alerts
# apps
# argocd-apps
# blueprint
# common
# community
# community-handbook
# continuous-delivery
# continuous-deployment
# curator
# espresso-series
# example-acm-install
# hetzner-baremetal-openshift
# hitchhikers-guide
# installplan-operator
# odh-dashboard
# operate-first-twitter
# operate-first.github.io
# opfcli
# schema-store
# SRE
# sre-apprenticeship
# support
# template
# toolbox
# workshop-apps
# amqp-client
# ansible-role-ansible_bastion
# ansible-role-firewall_facts
# ansible-role-freeipa
# ansible-role-httpd
# ansible-role-ipa_facts
# ansible-role-mariadb
# ansible-role-openssh
# ansible-role-polyinst_tmp
# ansible-role-rsyslog
# ansible-role-salt_transport
# ansible-role-selinux
# ansible-role-swap_file
# ansible-role-web_builder
# apps.fp.o
# comminfra-docs-sle-template
# community-website
# event-tools
# github-pluto-feeds
# github-pluto-moderate-posts
# jekyll-haml
# middleman-planet
# middleman-springboard
# moderated_planet_prototype
# mountpoint
# mw2md
# posse-tos-logos
# Practical-OSS-Exploration-textbook
# project-presos
# rh-events
# s2i-golang
# s2i-middleman
# sensor
# strapping-mediawiki
# tos-repository
# twitter-stats
# DO180-apps
# documentation
# how-do-I-documentation
# nlp-tweet-sentiments
# notebook-samples
# odh-s2i-project-cookiecutter
# odh-s2i-project-simple
# odh-s2i-scripts
# pilot-test-code
# postgres-operator-examples
# pricingnbs
# pytorch-diabetes
# pytorch-openvino
# pytorch-openvino-1
# RHSummit2019
# test-repo-lb
# testGPUs
# tgtaegdfg
# weather_data_elyra_pipeline_example
# welly-geoscience
# sandiego

# %%
# store the repos into a list
repos = list(g.get_user().get_repos())

# %%
repo = repos[1]
print(repo.raw_data)
# Out:
# {'id': 269347258, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNjkzNDcyNTg=', 'name': 'ai-ci', 'full_name': 'AICoE/ai-ci', 'private': True, 'owner': {'login': 'AICoE', 'id': 33660954, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNjYwOTU0', 'avatar_url': 'https://avatars.githubusercontent.com/u/33660954?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/AICoE', 'html_url': 'https://github.com/AICoE', 'followers_url': 'https://api.github.com/users/AICoE/followers', 'following_url': 'https://api.github.com/users/AICoE/following{/other_user}', 'gists_url': 'https://api.github.com/users/AICoE/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/AICoE/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/AICoE/subscriptions', 'organizations_url': 'https://api.github.com/users/AICoE/orgs', 'repos_url': 'https://api.github.com/users/AICoE/repos', 'events_url': 'https://api.github.com/users/AICoE/events{/privacy}', 'received_events_url': 'https://api.github.com/users/AICoE/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/AICoE/ai-ci', 'description': 'This is a continuous integration of a machine learning stack.', 'fork': False, 'url': 'https://api.github.com/repos/AICoE/ai-ci', 'forks_url': 'https://api.github.com/repos/AICoE/ai-ci/forks', 'keys_url': 'https://api.github.com/repos/AICoE/ai-ci/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/AICoE/ai-ci/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/AICoE/ai-ci/teams', 'hooks_url': 'https://api.github.com/repos/AICoE/ai-ci/hooks', 'issue_events_url': 'https://api.github.com/repos/AICoE/ai-ci/issues/events{/number}', 'events_url': 'https://api.github.com/repos/AICoE/ai-ci/events', 'assignees_url': 'https://api.github.com/repos/AICoE/ai-ci/assignees{/user}', 'branches_url': 'https://api.github.com/repos/AICoE/ai-ci/branches{/branch}', 'tags_url': 'https://api.github.com/repos/AICoE/ai-ci/tags', 'blobs_url': 'https://api.github.com/repos/AICoE/ai-ci/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/AICoE/ai-ci/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/AICoE/ai-ci/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/AICoE/ai-ci/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/AICoE/ai-ci/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/AICoE/ai-ci/languages', 'stargazers_url': 'https://api.github.com/repos/AICoE/ai-ci/stargazers', 'contributors_url': 'https://api.github.com/repos/AICoE/ai-ci/contributors', 'subscribers_url': 'https://api.github.com/repos/AICoE/ai-ci/subscribers', 'subscription_url': 'https://api.github.com/repos/AICoE/ai-ci/subscription', 'commits_url': 'https://api.github.com/repos/AICoE/ai-ci/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/AICoE/ai-ci/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/AICoE/ai-ci/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/AICoE/ai-ci/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/AICoE/ai-ci/contents/{+path}', 'compare_url': 'https://api.github.com/repos/AICoE/ai-ci/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/AICoE/ai-ci/merges', 'archive_url': 'https://api.github.com/repos/AICoE/ai-ci/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/AICoE/ai-ci/downloads', 'issues_url': 'https://api.github.com/repos/AICoE/ai-ci/issues{/number}', 'pulls_url': 'https://api.github.com/repos/AICoE/ai-ci/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/AICoE/ai-ci/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/AICoE/ai-ci/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/AICoE/ai-ci/labels{/name}', 'releases_url': 'https://api.github.com/repos/AICoE/ai-ci/releases{/id}', 'deployments_url': 'https://api.github.com/repos/AICoE/ai-ci/deployments', 'created_at': '2020-06-0 ...

# %%
# get the 'main' branch and print the raw data
branch = repo.get_branch("master")
print(branch.raw_data)
# get the first commit item form commits
commit = None
for c in repo.get_commits():
    commit = c
    break # we break here to only have the first iteration
# print the commit raw data
print(commit)
# Out:
# {'name': 'master', 'commit': {'sha': '9e6126b2d656a5b4d10be766c2ac26de8f0b5970', 'node_id': 'MDY6Q29tbWl0MjY5MzQ3MjU4OjllNjEyNmIyZDY1NmE1YjRkMTBiZTc2NmMyYWMyNmRlOGYwYjU5NzA=', 'commit': {'author': {'name': 'Christoph Görn', 'email': 'goern@redhat.com', 'date': '2020-06-04T12:35:39Z'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'date': '2020-06-04T12:35:39Z'}, 'message': 'Create README.md', 'tree': {'sha': 'be9ce2a6023143021a97ea7870b36e2778820d77', 'url': 'https://api.github.com/repos/AICoE/ai-ci/git/trees/be9ce2a6023143021a97ea7870b36e2778820d77'}, 'url': 'https://api.github.com/repos/AICoE/ai-ci/git/commits/9e6126b2d656a5b4d10be766c2ac26de8f0b5970', 'comment_count': 0, 'verification': {'verified': True, 'reason': 'valid', 'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=qTwR\n-----END PGP SIGNATURE-----\n', 'payload': 'tree be9ce2a6023143021a97ea7870b36e2778820d77\nparent df4c2cfb9e0fab6c27dbf019219cfe9e8f35cea9\nauthor Christoph Görn <goern@redhat.com> 1591274139 +0200\ncommitter GitHub <noreply@github.com> 1591274139 +0200\n\nCreate README.md'}}, 'url': 'https://api.github.com/repos/AICoE/ai-ci/commits/9e6126b2d656a5b4d10be766c2ac26de8f0b5970', 'html_url': 'https://github.com/AICoE/ai-ci/commit/9e6126b2d656a5b4d10be766c2ac26de8f0b5970', 'comments_url': 'https://api.github.com/repos/AICoE/ai-ci/commits/9e6126b2d656a5b4d10be766c2ac26de8f0b5970/comments', 'author': {'login': 'goern', 'id': 260331, 'node_id': 'MDQ6VXNlcjI2MDMzMQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/260331?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/goern', 'html_url': 'https://github.com/goern', 'followers_url': 'https://api.github.com/users/goern/followers', 'following_url': 'https://api.github.com/users/goern/following{/other_user}', 'gists_url': 'https://api.github.com/users/goern/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/goern/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/goern/subscriptions', 'organizations_url': 'https://api.github.com/users/goern/orgs', 'repos_url': 'https://api.github.com/users/goern/repos', 'events_url': 'https://api.github.com/users/goern/events{/privacy}', 'received_events_url': 'https://api.github.com/users/goern/received_events', 'type': 'User', 'site_admin': False}, 'committer': {'login': 'web-flow', 'id': 19864447, 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3', 'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/web-flow', 'html_url': 'https://github.com/web-flow', 'followers_url': 'https://api.github.com/users/web-flow/followers', 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}', 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions', 'organizations_url': 'https://api.github.com/users/web-flow/orgs', 'repos_url': 'https://api.github.com/users/web-flow/repos', 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}', 'received_events_url': 'https://api.github.com/users/web-flow/received_events', 'type': 'User', 'site_admin': False}, 'parents': [{'sha': 'df4c2cfb9e0fab6c27dbf019219cfe9e8f35cea9', 'url': 'https://api.github.com/repos/AICoE/ai-ci/commits/df4c2cfb9e0fab6c27dbf019219cfe9e8f35cea9', 'html_url': 'https://github.com/AICoE/ai-ci/commit/df4c2cfb9e0fab6c27dbf019219cfe9e8f35cea9'}]}, '_links': {'self': 'https://api.github.com/repos/AICoE/ai-ci/branches/mast ...
# Commit(sha="9e6126b2d656a5b4d10be766c2ac26de8f0b5970")

# %%
commits_data = {
"repo_id": int(repo.id),
"commit_sha": commit.sha,
"commit_message": commit.commit.message,
"commit_author_name": commit.commit.author.name,
"commit_author_email": commit.commit.author.email,
"commit_author_date": commit.commit.author.date,
"commit_committer_name": commit.commit.committer.name,
"commit_committer_email": commit.commit.committer.email,
"commit_committer_date": commit.commit.committer.date,
"author_login": commit.author.login,
"author_id": commit.author.id,
"author_avatar_url": commit.author.avatar_url,
"author_type": commit.author.type,
"committer_login": commit.committer.login,
"committer_id": commit.committer.id,
"committer_avatar_url": commit.committer.avatar_url,
"committer_type": commit.committer.type,
"stats_addtions": commit.stats.additions,
"stats_deletions": commit.stats.deletions,
"stats_total": commit.stats.total
}

# %%
#file_data = {
#"id": ,
#"commit_id": ,
#"repo_id": ,
#"file_name": ,
#"addtions": ,
#"deletions": ,
#"changes": ,
#"status":
#}

# %%
repo_data = {
"id": repo.id,
"name": repo.name,
"owner": repo.owner.login,
"fullname": repo.full_name,
"description": repo.description,
"url": repo.url,
"pushed_date": int(repo.pushed_at.timestamp()),
"created_date": int(repo.created_at.timestamp()),
"updated_date": int(repo.updated_at.timestamp()),
"size": repo.size,
"stars": repo.stargazers_count,
"forks": repo.forks_count,
"watchers": repo.watchers_count,
"language": repo.language,
"topics": ",".join(repo.get_topics()),
}

# %%
branch_data = {
"id": repo.id,
"repo_id": int(repo.id),
"name": branch.name,
"commit_sha": branch.commit.sha,
"protected": int(branch.protected)
}

# %%
repo_columns = list(repo_data.keys())
branch_columns = list(branch_data.keys())
#file_columns = list(file_data.keys())
commits_columns = list(commits_data.keys())

# %%
values = [repo_data[k] for k in repo_columns]

# %%
query = """INSERT INTO repo {0} VALUES ({1})""".format(repo_columns, values)
print(query)
# Out:
# INSERT INTO repo ['id', 'name', 'owner', 'fullname', 'description', 'url', 'pushed_date', 'created_date', 'updated_date', 'size', 'stars', 'forks', 'watchers', 'language', 'topics'] VALUES ([269347258, 'ai-ci', 'AICoE', 'AICoE/ai-ci', 'This is a continuous integration of a machine learning stack.', 'https://api.github.com/repos/AICoE/ai-ci', 1591288539, 1591286255, 1592505073, 18, 0, 0, 0, None, ''])

# %%
#cursor.execute(query,list)

#cursor.commit()

# %%
cnx.close()
